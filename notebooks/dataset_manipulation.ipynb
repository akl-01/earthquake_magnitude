# %%
import pandas as pd

# %%
df = pd.read_csv("../data/earthquake_1995-2023.csv")

# %%
df
# Out:
#                                          title  magnitude         date_time  \
# 0             M 6.5 - 42 km W of Sola, Vanuatu        6.5  16-08-2023 12:47
# 1     M 6.5 - 43 km S of Intipucá, El Salvador        6.5  19-07-2023 00:22
# 2     M 6.6 - 25 km ESE of Loncopué, Argentina        6.6  17-07-2023 03:05
# 3        M 7.2 - 98 km S of Sand Point, Alaska        7.2  16-07-2023 06:48
# 4                     M 7.3 - Alaska Peninsula        7.3  16-07-2023 06:48
# ..                                         ...        ...               ...
# 995          M 7.1 - 85 km S of Tungor, Russia        7.1  27-05-1995 13:03
# 996     M 7.7 - 249 km E of Vao, New Caledonia        7.7  16-05-1995 20:12
# 997  M 6.9 - 27 km NNW of Maubara, Timor Leste        6.9  14-05-1995 11:33
# 998           M 6.6 - 10 km W of Aianí, Greece        6.6  13-05-1995 08:47
# 999  M 7.1 - 14 km NE of Cabatuan, Philippines        7.1  05-05-1995 03:53
#
# ...

# %%
fit_df = df.sample(frac=0.39, axis=0, random_state=10)

# %%
fit_df
# Out:
#                                                title  magnitude  \
# 841                       M 7.9 - South Indian Ocean        7.9
# 956   M 7.2 - 58 km WSW of Panguna, Papua New Guinea        7.2
# 544                 M 6.7 - 52 km NNW of Tomé, Chile        6.7
# 173             M 6.7 - 10 km SSW of Coquimbo, Chile        6.7
# 759   M 6.8 - 114 km ESE of Kokopo, Papua New Guinea        6.8
# ..                                               ...        ...
# 76                                M 7.3 - Flores Sea        7.3
# 969            M 6.6 - 106 km NE of Yelizovo, Russia        6.6
# 276                M 6.8 - 26 km W of Chauk, Myanmar        6.8
# 383    M 7.4 - 112 km S of Kirakira, Solomon Islands        7.4
# 272  M 6.8 - 76 km WNW of Kandrian, Papua New Guinea        6.8
#
#             date_time  cdi  mmi   alert  tsunami   sig net  nst   dmin   gap  \
# 841  18-06-2000 14:44    0    5     NaN        0   960  us  405  0.000   0.0
# ...

# %%
fit_df.to_csv("../data/earthquake_dataset.csv")

# %%
fit_df.index
# Out:
# Index([2893144,  503337,  433472, 1932628, 1690290, 3020503,  635283, 1777965,
#        1895803, 2792440,
#        ...
#         986282, 1386322, 2390166, 2733022,  472363, 2097486, 1609243,  563199,
#        1299201, 1967053],
#       dtype='int64', length=1343843)

# %%
real_time_data = df.drop(fit_df.index, axis=0)

# %%
real_time_data.to_csv("../data/real_time_data.csv")

# %%
real_time_data
# Out:
#                   time                                     place     status  \
# 2         631154083450                7 km W of Cobb, California   reviewed
# 4         631155824490                    16km N of Fillmore, CA   reviewed
# 7         631156431950      12 km E of Mammoth Lakes, California   reviewed
# 8         631156614070      11 km E of Mammoth Lakes, California   reviewed
# 9         631156620210            1 km W of Wilkeson, Washington   reviewed
# ...                ...                                       ...        ...
# 3445741  1690625310020                   4 km SW of Redlands, CA  automatic
# 3445742  1690625393345                           Southern Alaska  automatic
# 3445743  1690626164400                   16 km ESE of Julian, CA  automatic
# 3445748  1690627215940  12 km W of Alberto Oviedo Mota, B.C., MX  automatic
# 3445750  1690628937884                 35 km W of Karluk, Alaska  automatic
#
# ...

# %%
len(real_time_data) / 2
# Out:
# 1050954.0

# %%
real_time_data = pd.read_csv("../data/real_time_data.csv", index_col=0)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
real_time_data
# Out:
#                   time                                     place     status  \
# 2         631154083450                7 km W of Cobb, California   reviewed
# 4         631155824490                    16km N of Fillmore, CA   reviewed
# 7         631156431950      12 km E of Mammoth Lakes, California   reviewed
# 8         631156614070      11 km E of Mammoth Lakes, California   reviewed
# 9         631156620210            1 km W of Wilkeson, Washington   reviewed
# ...                ...                                       ...        ...
# 3445741  1690625310020                   4 km SW of Redlands, CA  automatic
# 3445742  1690625393345                           Southern Alaska  automatic
# 3445743  1690626164400                   16 km ESE of Julian, CA  automatic
# 3445748  1690627215940  12 km W of Alberto Oviedo Mota, B.C., MX  automatic
# 3445750  1690628937884                 35 km W of Karluk, Alaska  automatic
#
# ...

# %%
ent = next(real_time_data.iterrows())

# %%
ent[1]
# Out:
# time                                631154083450
# place                 7 km W of Cobb, California
# status                                  reviewed
# tsunami                                        0
# significance                                  19
# data_type                             earthquake
# magnitudo                                   1.11
# state                                 California
# longitude                            -122.806167
# latitude                                  38.821
# depth                                       3.22
# date            1990-01-01 00:34:43.450000+00:00
# Name: 2, dtype: object
